# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
file0 = "/Users/apple/Workspace/python3/JockeyForcast/ST_1200-ALL-WEATHER-Class4.csv"
dataset = pd.read_csv(file0)
finishTime = dataset.finishTime
place =dataset.place
plt.scatter(place, finishTime,  color='black')
plt.show()
